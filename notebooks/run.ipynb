# %%
from pathlib import Path
import sys

root_dir = Path.cwd().parent.resolve()
sys.path.append(str(root_dir))
from src.run import Run

# %%
run = Run('sattunet-rn-enet-wd4')

# %% [markdown]
# ### clear run data

# %%
# # clear run data
run.clear(weights=True)
# Out:
# Removed results: /home/mauro/projects/mauro_hammoniaca/.runs/sattunet-rn-enet-wd4/results
# Removed outputs: /home/mauro/projects/mauro_hammoniaca/.runs/sattunet-rn-enet-wd4/outputs
# Removed data folder: /home/mauro/projects/mauro_hammoniaca/.data/sattunet-rn-enet-wd4
