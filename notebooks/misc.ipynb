# %%
from pathlib import Path
import sys
import torch
import pandas as pd

root_dir = Path.cwd().parent.resolve()
sys.path.append(str(root_dir))
from src.run import Run
from src.plotter import Plotter

# %%
p = Plotter('sattunet-rn-e104-wd4')

# %%
p.run.get_last_epoch('scheduler')
# Out:
# 100

# %%
p.torch_to_pd('scheduler', save=True)
# Out:
#     factor  min_lrs  patience  verbose  cooldown  cooldown_counter  threshold  \
# 0      0.5        0         5    False         0                 0     0.0001
# 1      0.5        0         5    False         0                 0     0.0001
# 2      0.5        0         5    False         0                 0     0.0001
# 3      0.5        0         5    False         0                 0     0.0001
# 4      0.5        0         5    False         0                 0     0.0001
# ..     ...      ...       ...      ...       ...               ...        ...
# 95     0.5        0         5    False         0                 0     0.0001
# 96     0.5        0         5    False         0                 0     0.0001
# 97     0.5        0         5    False         0                 0     0.0001
# 98     0.5        0         5    False         0                 0     0.0001
# 99     0.5        0         5    False         0                 0     0.0001
#
#         best  num_bad_epochs  mode_worse           eps  last_epoch  _last_lr  \
# 0   2.067821               0         inf  1.000000e-08           1    0.0010
# 1   1.559373               0         inf  1.000000e-08           2    0.0010
# 2   1.443323               0         inf  1.000000e-08           3    0.0010
# 3   1.336120               0         inf  1.000000e-08           4    0.0010
# 4   1.253825               0         inf  1.000000e-08           5    0.0010
# ..       ...             ...         ...           ...         ...       ...
# 95  0.600797               0         inf  1.000000e-08          96    0.0005
# 96  0.600797               1         inf  1.000000e-08          97    0.0005
# 97  0.600797               2         inf  1.000000e-08          98    0.0005
# 98  0.582286               0         inf  1.000000e-08          99    0.0005
# 99  0.582286               1         inf  1.000000e-08         100    0.0005
#
#     Epoch
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
#
# [100 rows x 14 columns]

# %%
p.cm('val')
