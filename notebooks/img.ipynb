# %%
import sys
import os
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)
import numpy as np

from datasets.rescuenet_resized import Dataset
from datasets import joint_transforms
import torchvision.transforms as transforms

from src.imgs import Img

import matplotlib.pyplot as plt

# %%
d = Dataset(split='test', scale=704)
img = Img(d)
img.print_dataset_colors()

# %%
img.view(7)

# %%
index = 15
element = d[index]
type(element), element[0].shape, element[1].shape
# Out:
# (tuple, torch.Size([3, 704, 938]), torch.Size([704, 938]))

# %%
img.view_img(1)
img.view_label(1)
img.view_overlay(1)

# %%
img.visualize_images_with_superposition(3)

# %%
el = img[22]
img.visualize_images_with_superposition(el[0], el[1])
